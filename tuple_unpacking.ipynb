# %%
a,b,(c,d) = 4,5,(6,7)

# %%
a,b,*c = 4,5,6,7,8

print(c)
print(type(c))
# Out:
# [6, 7, 8]
# <class 'list'>

# %%
a,b,*c = [4,5,6,7,8]

print(c)
print(type(c))
# Out:
# [6, 7, 8]
# <class 'list'>
